# %% [markdown]
# 정답률을 높이고자 '데이타 수량 늘리기'를 자주 사용한다.
#
# 사진을 회전하거나 반전하는 것이다.
#
# 왜냐하면 사람이 보기에 같은 그림이라도 컴퓨터는 사진을 조금만 회전해도 다른 이미지로 인식한다.
#
# ## 그러나 이번 이미지로는 정답률이 현저히 더 낮게 나온다.
# 다른 그림으로 다시 확인하길

# %%
# 동일한 모델

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop

# CNN 모델 정의하기
def def_model(in_shape, nb_classes):
    model = Sequential()
    model.add(Conv2D(32,
              kernel_size=(3, 3),
              activation='relu',
              input_shape=in_shape))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    return model

# 컴파일하고 모델 반환하기
def get_model(in_shape, nb_classes):
    model = def_model(in_shape, nb_classes)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    return model

# %% [markdown]
# cnn_model.py 파일에 함수를 선언하고 호출하는 방식으로 진행

# %%
import cnn_model

from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import cv2


# 입력과 출력 지정하기
im_rows = 32 # 이미지의 높이
im_cols = 32 # 이미지의 너비
im_color = 3 # 이미지의 색공간
in_shape = (im_rows, im_cols, im_color)
nb_classes = 5

# 사진 데이터 읽어 들이기
photos = np.load('image/photos.npz')
x = photos['x']
y = photos['y']

# 읽어들인 데이터를 3차원 배열로 변환하기
x = x.reshape(-1, im_rows, im_cols, im_color)
x = x.astype('float32') / 255
# 레이블 데이터를 One-hot 형식으로 변환하기
y = to_categorical(y.astype('int32'), nb_classes)

# 학습 전용과 테스트 전용으로 구분하기
x_train, x_test, y_train, y_test = train_test_split(
    x, y, train_size=0.8)

# 학습 전용 데이터 수 늘리기 --- (*1)
x_new = []
y_new = []
for i, xi in enumerate(x_train):
    yi = y_train[i]
    for ang in range(-30, 30, 5):
        # 회전 시키기 --- (*2)
        center = (16, 16) # 회전 중심
        mtx = cv2.getRotationMatrix2D(center, ang, 1.0)
        xi2 = cv2.warpAffine(xi, mtx, (32, 32))
        x_new.append(xi2)
        y_new.append(yi)
        # 좌우 반전 --- (*3)
        xi3 = cv2.flip(xi2, 1)
        x_new.append(xi3)
        y_new.append(yi)

# 이미지를 늘린 데이터를 학습 데이터로 사용하기
print('수량을 늘리기 전=', len(y_train))
x_train = np.array(x_new)
y_train = np.array(y_new)
print('수량을 늘린 후=', len(y_train))
# Out:
# 수량을 늘리기 전= 903
# 수량을 늘린 후= 21672

# %%
# CNN 모델 만들기 --- (*6)
model = cnn_model.get_model(in_shape, nb_classes)

# 학습 실행하기 --- (*8) 시간소요 많음 ( 30분이상 )
hist = model.fit(x_train, y_train,
          batch_size=64,
          epochs=50,
          verbose=1,
          validation_data=(x_test, y_test))

# 모델 평가하기 --- (*9)
score = model.evaluate(x_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# Epoch 1/50
# 339/339 [==============================] - 47s 137ms/step - loss: 1.3868 - accuracy: 0.4162 - val_loss: 1.0761 - val_accuracy: 0.5088
# Epoch 2/50
# 339/339 [==============================] - 47s 140ms/step - loss: 0.8646 - accuracy: 0.6559 - val_loss: 1.0392 - val_accuracy: 0.6283
# Epoch 3/50
# 339/339 [==============================] - 55s 163ms/step - loss: 0.5947 - accuracy: 0.7643 - val_loss: 1.1565 - val_accuracy: 0.6195
# Epoch 4/50
# 339/339 [==============================] - 52s 155ms/step - loss: 0.3956 - accuracy: 0.8521 - val_loss: 1.5413 - val_accuracy: 0.5973
# Epoch 5/50
# 339/339 [==============================] - 49s 146ms/step - loss: 0.2635 - accuracy: 0.9039 - val_loss: 1.9148 - val_accuracy: 0.5664
# Epoch 6/50
# 339/339 [==============================] - 54s 159ms/step - loss: 0.2038 - accuracy: 0.9308 - val_loss: 1.8759 - val_accuracy: 0.6150
# Epoch 7/50
# 339/339 [==============================] - 51s 151ms/step - loss: 0.1667 - accuracy: 0.9405 - val_loss: 2.2462 - val_accuracy: 0.6062
# Epoch 8/50
# 339/339 [==============================] - 58s 172ms/step - loss: 0.1314 - accuracy: 0.9538 - val_loss: 2.9316 - val_accuracy: 0.6150
# Epoch 9/50
# 339/339 [==============================] - 53s 157ms/step - loss: 0.1181 - accuracy: 0.9615 - val_loss: 2.3791 - val_accuracy: 0.6283
# Epoch 10/50
# 339/339 [==============================] - 52s 155ms/step - loss: 0.1077 - accuracy: 0.9659 - val_loss: 2.5667 - val_accuracy: 0.6195
# Epoch 11/50
# 339/339 [==============================] - 53s 158ms/step - loss: 0.0966 - accuracy: 0.9691 - val_loss: 3.4091 - val_accuracy: 0.6195
# Epoch 12/50
# 339/339 [==============================] - 55s 162ms/step - loss: 0.1045 - accuracy: 0.9674 - val_loss: 3.7426 - val_accuracy: 0.6150
# Epoch 13/50
# 339/339 [==============================] - 55s 161ms/step - loss: 0.0908 - accuracy: 0.9733 - val_loss: 2.8336 - val_accuracy: 0.6018
# Epoch 14/50
# 339/339 [==============================] - 51s 152ms/step - loss: 0.1058 - accuracy: 0.9714 - val_loss: 4.4133 - val_accuracy: 0.6283
# Epoch 15/50
# 339/339 [==============================] - 59s 173ms/step - loss: 0.1092 - accuracy: 0.9677 - val_loss: 2.2820 - val_accuracy: 0.6195
# Epoch 16/50
# 339/339 [==============================] - 51s 152ms/step - loss: 0.0928 - accuracy: 0.9733 - val_loss: 4.5489 - val_accuracy: 0.6150
# Epoch 17/50
# 339/339 [==============================] - 59s 173ms/step - loss: 0.0913 - accuracy: 0.9738 - val_loss: 3.8256 - val_accuracy: 0.6018
# Epoch 18/50
# 339/339 [==============================] - 51s 150ms/step - loss: 0.1052 - accuracy: 0.9717 - val_loss: 3.5634 - val_accuracy: 0.6150
# Epoch 19/50
# 339/339 [==============================] - 51s 150ms/step - loss: 0.1089 - accuracy: 0.9699 - val_loss: 4.3052 - val_accuracy: 0.5575
# Epoch 20/50
# 339/339 [==============================] - 56s 165ms/step - loss: 0.1138 - accuracy: 0.9706 - val_loss: 3.0656 - val_accuracy: 0.6504
# Epoch 21/50
# 339/339 [==============================] - 49s 144ms/step - loss: 0.1012 - accuracy: 0.9704 - val_loss: 4.6416 - val_accuracy: 0.5708
# Epoch 22/50
# 339/339 [==============================] - 56s 164ms/step - loss: 0.1246 - accuracy: 0.9694 - val_loss: 3.0124 - val_accuracy: 0.6018
# Epoch 23/50
# 339/339 [==============================] - 52s 154ms/step - loss: 0.1255 - accuracy: 0.9692 - val_loss: 3.6625 - val_accuracy: 0.5929
# Epoch 24/50
# 339/339 [==============================] - 51s 151ms/step - loss: 0.1185 - accuracy: 0.9697 - val_loss: 4.6375 - val_accuracy: 0.6239
# Epoch 25/50
# 339/339 [==============================] - 56s 165ms/step - loss: 0.1398 - accuracy: 0.9642 - val_loss: 5.2982 - val_accuracy: 0.5796
# Epoch 26/50
# 339/339 [==============================] - 49s 145ms/step - loss: 0.1517 - accuracy: 0.9665 - val_loss: 5.6078 - val_accuracy: 0.5796
# Epoch 27/50
# 339/339 [==============================] - 55s 163ms/step - loss: 0.1320 - accuracy: 0.9675 - val_loss: 3.3677 - val_accuracy: 0.6195
# Epoch 28/50
# 339/339 [==============================] - 51s 151ms/step - loss: 0.1290 - accuracy: 0.9668 - val_loss: 4.6168 - val_accuracy: 0.6372
# Epoch 29/50
# 339/339 [==============================] - 51s 150ms/step - loss: 0.1339 - accuracy: 0.9695 - val_loss: 4.8707 - val_accuracy: 0.6150
# Epoch 30/50
# 339/339 [==============================] - 55s 164ms/step - loss: 0.1489 - accuracy: 0.9656 - val_loss: 4.9318 - val_accuracy: 0.6239
# Epoch 31/50
# 339/339 [==============================] - 49s 146ms/step - loss: 0.1642 - accuracy: 0.9630 - val_loss: 3.5196 - val_accuracy: 0.5708
# Epoch 32/50
# 339/339 [==============================] - 56s 165ms/step - loss: 0.1640 - accuracy: 0.9626 - val_loss: 5.1938 - val_accuracy: 0.6327
# Epoch 33/50
# 339/339 [==============================] - 51s 149ms/step - loss: 0.1824 - accuracy: 0.9617 - val_loss: 4.0316 - val_accuracy: 0.6106
# Epoch 34/50
# 339/339 [==============================] - 51s 151ms/step - loss: 0.1576 - accuracy: 0.9673 - val_loss: 4.1553 - val_accuracy: 0.5929
# Epoch 35/50
# 339/339 [==============================] - 56s 165ms/step - loss: 0.1634 - accuracy: 0.9641 - val_loss: 6.0739 - val_accuracy: 0.6062
# Epoch 36/50
# 339/339 [==============================] - 50s 146ms/step - loss: 0.1993 - accuracy: 0.9630 - val_loss: 4.1833 - val_accuracy: 0.5973
# Epoch 37/50
# 339/339 [==============================] - 56s 164ms/step - loss: 0.1728 - accuracy: 0.9623 - val_loss: 3.7683 - val_accuracy: 0.6460
# Epoch 38/50
# 339/339 [==============================] - 51s 150ms/step - loss: 0.1767 - accuracy: 0.9642 - val_loss: 5.0478 - val_accuracy: 0.6372
# Epoch 39/50
# 339/339 [==============================] - 51s 149ms/step - loss: 0.1809 - accuracy: 0.9611 - val_loss: 5.5634 - val_accuracy: 0.5929
# Epoch 40/50
# 339/339 [==============================] - 55s 162ms/step - loss: 0.1844 - accuracy: 0.9595 - val_loss: 6.3315 - val_accuracy: 0.5796
# Epoch 41/50
# 339/339 [==============================] - 49s 144ms/step - loss: 0.1698 - accuracy: 0.9658 - val_loss: 5.9785 - val_accuracy: 0.6150
# Epoch 42/50
# 339/339 [==============================] - 55s 163ms/step - loss: 0.2024 - accuracy: 0.9625 - val_loss: 3.5744 - val_accuracy: 0.5885
# Epoch 43/50
# 339/339 [==============================] - 51s 149ms/step - loss: 0.2025 - accuracy: 0.9576 - val_loss: 8.3784 - val_accuracy: 0.6327
# Epoch 44/50
# 339/339 [==============================] - 51s 151ms/step - loss: 0.1959 - accuracy: 0.9621 - val_loss: 5.2887 - val_accuracy: 0.6460
# Epoch 45/50
# 339/339 [==============================] - 55s 163ms/step - loss: 0.2205 - accuracy: 0.9607 - val_loss: 4.5844 - val_accuracy: 0.5841
# Epoch 46/50
# 339/339 [==============================] - 51s 149ms/step - loss: 0.1947 - accuracy: 0.9600 - val_loss: 3.8732 - val_accuracy: 0.6062
# Epoch 47/50
# 339/339 [==============================] - 56s 165ms/step - loss: 0.1812 - accuracy: 0.9594 - val_loss: 4.7002 - val_accuracy: 0.6062
# Epoch 48/50
# 339/339 [==============================] - 50s 148ms/step - loss: 0.1982 - accuracy: 0.9593 - val_loss: 6.0504 - val_accuracy: 0.6327
# Epoch 49/50
# 339/339 [==============================] - 53s 155ms/step - loss: 0.1963 - accuracy: 0.9618 - val_loss: 5.4109 - val_accuracy: 0.6150
# Epoch 50/50
# 339/339 [==============================] - 55s 162ms/step - loss: 0.2433 - accuracy: 0.9553 - val_loss: 6.2486 - val_accuracy: 0.6327
# 8/8 [==============================] - 0s 15ms/step - loss: 6.2486 - accuracy: 0.6327
# 정답률= 0.6327433586120605 loss= 6.2486443519592285

# %%
# 학습 상태를 그래프로 그리기 --- (*10)
# 정답률 추이를 그래프로 그리기
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# 손실 추이를 그래프로 그리기
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

model.save_weights('./image/photos-model.hdf5')
